# %%
class Production_Ceh():
  def __init__(self, azot_acid):
    self.acid = azot_acid
  def produce_azot_acid(self):
    pass

class Camera():
  pass

class Catalizator():
  def __init__(self, good_for1: bool, good_for2: bool):
    self.good_for_1 = good_for1
    self.good_for_2 = good_for2

class oksid_FE(Catalizator):
  pass

class olovo_based(Catalizator):
  pass

class molly(Catalizator):
  pass

class platina_300(Catalizator):
  pass

class rutenii(Catalizator):
  pass

class Par():
  def __init__(self, temp: float, pressure: float, percent: float):
    self.temp = temp
    self.pressure = pressure
    self.percent = percent

class Amiak_Batch():
  def __init__(self, cat_licker: Catalizator):
    self.cat_licker = cat_licker

class Camera_1(Camera):
  def __init__(self, parr: Par, gas, catalizat: Catalizator):
    self.par = parr
    self.gas = gas
    self.catalit = catalizat

  def get_amiak(self):
    pass

  def further_amiak(self):
    return "ami_batch"

class Dioxxxyd_Batch():
  def __init__(self, cataliz: Catalizator):
    self.cataliz = cataliz

class Camera_2(Camera):
  def __int__(self, ami_batch: Amiak_Batch, air_percent: float):
    self.ami_batch = ami_batch
    self.air_percent = air_percent
  def create_dioxxyd(self):
    pass

class Filter():
  def __int__(self, firma_name: str, series: str, dirty_state: float, nado_menyat: bool):
    self.firm = firma_name
    self.series = series
    self.dirty_state = dirty_state
    self.nado_menyat = nado_menyat

class Truba():
  def __int__(self, filter_now: Filter):
    self.filter = filter_now
  def proverka_filter(self):
    pass
  def smena_filter(self):
    pass
  def flirting(self):
    return "filtered_oxxxy"

class Camera_3(Camera):
  def __init__(self, water, oxxy):
    self.water = water
    self.oxxy = oxxy
  def get_filtered_oxxy_batch(self):
    pass
  def start_absorbation(self):
    pass
  def pass_absorbed_batch(self):
    pass

class Camera_4(Camera):
  def __init__(self, absorbed_batch):
    self.absorbed_batch = absorbed_batch

  def receive_absorbed_batch(self):
    pass
  def start_concentration(self):
    pass
  def get_final_product(self):
    pass
